# %%
import polars as pl

# %%
df = pl.read_excel("KE_QoS_Report_20260315.xlsx")
df
# Out:
# shape: (572, 183)
# ┌─────────┬────────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ OPCO    ┆ KPI        ┆ Measureme ┆ 16-09-202 ┆ … ┆ 12-03-202 ┆ 13-03-202 ┆ 14-03-202 ┆ 15-03-202 │
# │ ---     ┆ ---        ┆ nt        ┆ 5         ┆   ┆ 6         ┆ 6         ┆ 6         ┆ 6         │
# │ str     ┆ str        ┆ ---       ┆ ---       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---       │
# │         ┆            ┆ str       ┆ str       ┆   ┆ str       ┆ str       ┆ str       ┆ str       │
# ╞═════════╪════════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ KE      ┆ 2G RNA     ┆ 24 Hrs    ┆ 99.904420 ┆ … ┆ 99.905699 ┆ 99.876480 ┆ 99.913197 ┆ 99.919977 │
# │         ┆            ┆           ┆ 381       ┆   ┆ 595       ┆ 852       ┆ 565       ┆ 731       │
# │ KE      ┆ 3G RNA     ┆ 24 Hrs    ┆ 99.9      ┆ … ┆ 99.91     ┆ 99.88     ┆ 99.91     ┆ 99.92     │
# ...
